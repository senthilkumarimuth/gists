# %% [markdown]
# ## What is Cross Entropy?
#
# Cross Entroy in General:
#
# It measures the difference between two probability distributions. A lower cross entropy value indicates that the predicted probabilities are closer to the true labels.
#
#
#
# ![Untitled picture.png](<attachment:Untitled picture.png>)
#
#
#
# Note:
#
# cross entropy is from information theory. there is a term negative log likelyhood which is also same as entropy but is veiwed in statictical view, essentially both means same.

# %% [markdown]
# ## Binary Corss entropy Or log loss:
#
# We use cross entropy as a cost funtion. Cross entropy otherwise called as log loss
#
#
# ![Untitled picture.png](<attachment:Untitled picture.png>)

# %% [markdown]
# ## Categorical cross-entropy:
#
# This to be used as loss function when categorical data has very few category.
#
#
# Category variable ---> OneHot encode ---> Categorical cross entropy
#
# ![image-6.png](attachment:image-6.png)

# %% [markdown]
# # Sparse categorical cross-entropy:
#
# Now, it could be the case that your dataset is not categorical at first ... and possibly, that it is too large in order to use to_categorical. In that case, it would be rather difficult to use categorical crossentropy, since it is dependent on categorical data.
#
# However, when you have integer targets instead of categorical vectors as targets, you can use sparse categorical crossentropy. It's an integer-based version of the categorical crossentropy loss function, which means that we don't have to convert the targets into categorical format anymore.
#
# Category variable ---> label encode ---> sparse categorical cross entropy

# %% [markdown]
# ## Why Cross-entropy is better than classification error, mean squared error?
#
# ![Untitled picture.png](<attachment:Untitled picture.png>)
#
#
#
# Cross entropy helps the NN to learn faster when the error is too small. ex. ypred=0.000001, y=1 and ypre=0.0001, y=1. Here the ypred has improved but change is small. Mean squared error will not consider these error difference much and will not assist the NN to learn. On the other hand, cross entropy has log function and it helps NN to learn faster. i.e very sensitive for change in values of ypred and y.
