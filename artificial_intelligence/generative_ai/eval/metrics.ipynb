# %% [markdown]
# # Retrieval
#
# ### Non LLM
#
# 1. MMR(Mean Reciprocal Rank)
#
# MRR is used to evaluate the retrieval component of the system’s performance in retrieving pertinent documents that facilitate the development of accurate and pertinent responses in the context of Retrieval-Augmented development (RAG).
#
# ![image-4.png](attachment:image-4.png)
#
# Example
#
# Let’s see an example for MRR.
#
# ![image-5.png](attachment:image-5.png)
#
# In the above image we can see that MRR for Q1 is ⅓ as the correct retrieved node is at 3rd position. Hence the MRR is calculated as
#
# ![image-6.png](attachment:image-6.png)
#
# 2. Hit rate
#
#
# The calculation of Hit Rate involves dividing the total number of queries by the frequency with which the pertinent item appears in the top-N recommendations. In terms of math, it is stated as:
#
# ![image-2.png](attachment:image-2.png)
#
# Example
#
# Let’s get a better understanding with an example. We have three queries Q1, Q2, Q3. We also know the exact node to be picked for those queries. Actual Nodes for those queries are N1, N2, N3. Now upon sending those queries we receive nodes from our Retriever. The retrieved nodes for those queries are as mentioned below:
#
# ![image-3.png](attachment:image-3.png)
#
# Hit Rate
# We can see that our retriever has retrieved the correct node for Q1 and Q2. It did not perform well with Q3. Hence the Hit Rate is 1 for Q1, Q2 and 0 for Q3. Upon using our formula we can calculate the Hit Rate:
#
# ![image.png](attachment:image.png)
#
#
#
# ### LLM based
#
# 1. Context recall
# 2. Contex precision
#
# # Completion
#
# 1. RAGA - faithfulness
#
#
# 2. RAGA - Relevancy
#
#
# ### References
#
#
# Why Ragas
#
# Ragas framework provides evaluation metrics both compenent wise and end to end wise.
#
# Component-Wise Evaluation¶
#
#
#  Ragas offers metrics tailored for evaluating each component(LLM Aug + Retrieval)of your RAG pipeline in isolation
#
# ![image-7.png](attachment:image-7.png)
#
#
# End-to-End Evaluation¶
#
# Ragas provides metrics that can be employed to assess the overall performance of your pipeline, ensuring a comprehensive evaluation.
#
#     • Answer semantic similarity(ex cosine similarity of actual vs predicted)
#
#     • Answer correctness(f1 score)

# %% [markdown]
# # Metrices from MLflow and Databricks

# %% [markdown]
# ![Capture.PNG](attachment:Capture.PNG)

# %% [markdown]
# https://docs.databricks.com/aws/en/mlflow3/genai/eval-monitor/concepts/judges/pre-built-judges-scorers
